# %% [markdown]
# ## **Clase 4a y 4b (17/08/2023)**

# %% [markdown]
# ### <font color='green'>**Ejercicio Propuesto 16** </font>
#
# A partir del archivo *ParticipacionesMundiales.xslx*, responda:
#
# 1. ¿Cuál es la mayor cantidad de finales ganadas?
# 2. ¿Cuál es la mayor cantidad de finales disputadas?
# 3. ¿Cuál es la menor cantidad de participaciones?
# 4. ¿Cuáles son los tres mejores equipos?
# 5. ¿Cuáles son los tres peores equipos?
#
# ***Ayuda 1:*** El archivo se encuentra en la carpeta *Datos/Pandas*.
# ***Ayuda 2:*** Puede que le sea útil el método $describe$.
# ***Ayuda 3:*** Puede que le sean útiles los métodos $head$ y $tail$.

# %%
import pandas as pd

# %%
df = pd.read_excel('ParticipacionesMundiales.xlsx')
df.head(5)
# Out:
#     Selección  Títulos  Finales  Semifinales  Cuartos  Octavos  Primera Ronda  \
# 0      Brasil        5        7           11       17       19             22
# 1    Alemania        4        8           13       17       18             20
# 2      Italia        4        6            8        9       11             18
# 3   Argentina        3        6            6       11       14             18
# 4     Francia        2        4            7        9       10             16
#
#   Confederación
# 0      Conmebol
# 1          UEFA
# 2          UEFA
# 3      Conmebol
# 4          UEFA

# %%
resumen = df.describe()
resumen
# Out:
#          Títulos    Finales  Semifinales   Cuartos    Octavos  Primera Ronda
# count  20.000000  20.000000    20.000000  20.00000  20.000000      20.000000
# mean    1.100000   2.200000     4.150000   6.85000   8.800000      12.800000
# std     1.651156   2.607681     3.344674   4.33195   4.514305       4.572227
# min     0.000000   0.000000     1.000000   2.00000   3.000000       6.000000
# 25%     0.000000   0.000000     2.000000   3.00000   5.000000       9.000000
# 50%     0.000000   1.000000     2.500000   6.00000   8.500000      12.000000
# 75%     2.000000   3.250000     5.250000   9.00000  10.250000      16.000000
# max     5.000000   8.000000    13.000000  17.00000  19.000000      22.000000

# %% [markdown]
# 1. ¿Cuál es la mayor cantidad de finales ganadas?: 5 títulos

# %%
#[Fila, Columna]
cond = df.loc[:, 'Títulos'] == max(df.loc[:, 'Títulos']) #resumen.loc['max', 'Títulos']
df.loc[cond, :]
# Out:
#   Selección  Títulos  Finales  Semifinales  Cuartos  Octavos  Primera Ronda  \
# 0    Brasil        5        7           11       17       19             22
#
#   Confederación
# 0      Conmebol
