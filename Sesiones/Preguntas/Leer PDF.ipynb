# %%
# !pip install tabula-py #Linux o MAC
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 25.2 MB/s eta 0:00:00
# ...

# %%
import tabula as tb

# %%
df = tb.read_pdf('Documento 3.pdf', pages=1, silent=True)[0]
df
# Out:
#     Unnamed: 0    Unnamed: 1 Unnamed: 2   Unnamed: 3    Unnamed: 4  \
# 0          NaN           NaN        NaN      Ballots           NaN
# 1   Disability           NaN    Ballots          NaN           NaN
# 2          NaN  Participants        NaN  Incomplete/           NaN
# 3     Category           NaN  Completed          NaN      Accuracy
# 4          NaN           NaN        NaN   Terminated           NaN
# 5          NaN           NaN        NaN          NaN           NaN
# 6        Blind             5          1            4    34.5%, n=1
# 7   Low Vision             5          2            3     98.3% n=2
# 8          NaN           NaN        NaN          NaN  (97.7%, n=3)
# 9    Dexterity             5          4            1    98.3%, n=4
# 10    Mobility             3          3            0    95.4%, n=3
#
#             Results
# 0               NaN
# 1               NaN
# 2               NaN
# 3           Time to
# 4               NaN
# 5          complete
# ...

# %%
df.drop(index=[0,1,2,3,4,5], inplace=True)
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4          Results
# 6        Blind          5          1          4    34.5%, n=1    1199 sec, n=1
# 7   Low Vision          5          2          3     98.3% n=2    1716 sec, n=3
# 8          NaN        NaN        NaN        NaN  (97.7%, n=3)  (1934 sec, n=2)
# 9    Dexterity          5          4          1    98.3%, n=4  1672.1 sec, n=4
# 10    Mobility          3          3          0    95.4%, n=3    1416 sec, n=3

# %%
df.columns = [['Disability Category','Participants','Ballots Completed','Ballots Incomplete/Terminated','Results','Results'],
              ['','','','','Accuracy','Time to complete']]
df
# Out:
#    Disability Category Participants Ballots Completed  \
#
# 6                Blind            5                 1
# 7           Low Vision            5                 2
# 8                  NaN          NaN               NaN
# 9            Dexterity            5                 4
# 10            Mobility            3                 3
#
#    Ballots Incomplete/Terminated       Results
#                                       Accuracy Time to complete
# 6                              4    34.5%, n=1    1199 sec, n=1
# 7                              3     98.3% n=2    1716 sec, n=3
# 8                            NaN  (97.7%, n=3)  (1934 sec, n=2)
# 9                              1    98.3%, n=4  1672.1 sec, n=4
# 10                             0    95.4%, n=3    1416 sec, n=3

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[2,:] = list(df.iloc[1, 0:4]) + [df.iloc[2, 4], df.iloc[2, 5]]
df.iloc[:,4] = df.iloc[:,4].str.replace('(','').str.replace(')','')
df.iloc[:,5] = df.iloc[:,5].str.replace('(','').str.replace(')','')
df
# Out:
# <ipython-input-31-13149f49fb64>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.iloc[:,4] = df.iloc[:,4].str.replace('(','').str.replace(')','')
# <ipython-input-31-13149f49fb64>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.iloc[:,5] = df.iloc[:,5].str.replace('(','').str.replace(')','')
#   Disability Category Participants Ballots Completed  \
#
# 0               Blind            5                 1
# 1          Low Vision            5                 2
# 2          Low Vision            5                 2
# 3           Dexterity            5                 4
# 4            Mobility            3                 3
#
# ...
